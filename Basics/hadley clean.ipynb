# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('hadleydataset.csv')

# %%
df.head()
# Out:
#   country  year  m04  m514  m014  m1524  m2534  m3544  m4554  m5564  ...  f04  \
# 0      AD  1989  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...  NaN
# 1      AD  1990  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...  NaN
# 2      AD  1991  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...  NaN
# 3      AD  1992  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...  NaN
# 4      AD  1993  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...  NaN
#
#    f514  f014  f1524  f2534  f3544  f4554  f5564  f65  fu
# 0   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
# 1   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
# 2   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
# 3   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
# 4   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['country', 'year', 'm04', 'm514', 'm014', 'm1524', 'm2534', 'm3544',
#        'm4554', 'm5564', 'm65', 'mu', 'f04', 'f514', 'f014', 'f1524', 'f2534',
#        'f3544', 'f4554', 'f5564', 'f65', 'fu'],
#       dtype='object')

# %%
melted = df.melt(['country', 'year'],['m04', 'm514', 'm014', 'm1524', 'm2534', 'm3544',
       'm4554', 'm5564', 'm65', 'mu', 'f04', 'f514', 'f014', 'f1524', 'f2534',
       'f3544', 'f4554', 'f5564', 'f65', 'fu'],'sexage','cases')

# %%
melted.head()
# Out:
#   country  year sexage  cases
# 0      AD  1989    m04    NaN
# 1      AD  1990    m04    NaN
# 2      AD  1991    m04    NaN
# 3      AD  1992    m04    NaN
# 4      AD  1993    m04    NaN

# %%
melted['sex'] = melted['sexage'].str.slice(0,1)
melted['age'] =melted['sexage'].str.slice(1)

# %%
melted.head()
# Out:
#   country  year sexage  cases sex age
# 0      AD  1989    m04    NaN   m  04
# 1      AD  1990    m04    NaN   m  04
# 2      AD  1991    m04    NaN   m  04
# 3      AD  1992    m04    NaN   m  04
# 4      AD  1993    m04    NaN   m  04

# %%
melted.drop(['sexage'], axis=1,inplace=True)

# %%
melted.head()
# Out:
#   country  year  cases sex age
# 0      AD  1989    NaN   m  04
# 1      AD  1990    NaN   m  04
# 2      AD  1991    NaN   m  04
# 3      AD  1992    NaN   m  04
# 4      AD  1993    NaN   m  04

# %%
melted['age'] = melted['age'].map({'04':'0-4','514':'5-14','1524':'15-24','2534':'25-34',
                                  '3544':'35-44','4554':'45-54','5564':'55-64','65':'65+','u':np.nan})

# %%
melted.tail()
# Out:
#        country  year  cases sex  age
# 115375      ZW  2004    NaN   f  NaN
# 115376      ZW  2005    NaN   f  NaN
# 115377      ZW  2006    NaN   f  NaN
# 115378      ZW  2007    NaN   f  NaN
# 115379      ZW  2008    0.0   f  NaN

# %%
final=melted.dropna(subset=['cases'])

# %%
final.tail()
# Out:
#        country  year  cases sex  age
# 115195      VU  2008    0.0   f  NaN
# 115269      YE  2008    0.0   f  NaN
# 115323      ZA  2008    0.0   f  NaN
# 115350      ZM  2008    0.0   f  NaN
# 115379      ZW  2008    0.0   f  NaN

# %%
final.sort_values(['country', 'year', 'cases','age', 'sex'])
# Out:
#        country  year   cases sex    age
# 17313       AD  1996     0.0   m  15-24
# 23082       AD  1996     0.0   m  25-34
# 86541       AD  1996     0.0   f  35-44
# 92310       AD  1996     0.0   f  45-54
# 40389       AD  1996     0.0   m  55-64
# 103848      AD  1996     0.0   f    65+
# 46158       AD  1996     0.0   m    65+
# 69234       AD  1996     0.0   f    NaN
# 11544       AD  1996     0.0   m    NaN
# 75003       AD  1996     1.0   f  15-24
# 80772       AD  1996     1.0   f  25-34
# 34620       AD  1996     1.0   m  45-54
# 98079       AD  1996     1.0   f  55-64
# 28851       AD  1996     4.0   m  35-44
# 17314       AD  1997     0.0   m  15-24
# 92311       AD  1997     0.0   f  45-54
# 98080       AD  1997     0.0   f  55-64
# 69235       AD  1997     0.0   f    NaN
# 11545       AD  1997     0.0   m    NaN
# 75004       AD  1997     1.0   f  15-24
# 23083       AD  1997     1.0   m  25-34
# 40390       AD  1997     1.0   m  55-64
# ...

# %%
final.to_csv('final_hadleyclean.csv', index=False)
