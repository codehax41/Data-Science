# %% [markdown]
# # 911 Calls Capstone Project

# %% [markdown]
# For this capstone project we will be analyzing some 911 call data from [Kaggle](https://www.kaggle.com/mchirico/montcoalert). The data contains the following fields:
#
# * lat : String variable, Latitude
# * lng: String variable, Longitude
# * desc: String variable, Description of the Emergency Call
# * zip: String variable, Zipcode
# * title: String variable, Title
# * timeStamp: String variable, YYYY-MM-DD HH:MM:SS
# * twp: String variable, Township
# * addr: String variable, Address
# * e: String variable, Dummy variable (always 1)
#
# Just go along with this notebook and try to complete the instructions or answer the questions in bold using your Python and Data Science skills!

# %% [markdown]
# ## Data and Setup

# %% [markdown]
# ____
# ** Import numpy and pandas **

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ** Import visualization libraries and set %matplotlib inline. **

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ** Read in the csv file as a dataframe called df **

# %%
df=pd.read_csv('911.csv')

# %% [markdown]
# ** Check the info() of the df **

# %%
df.info
# Out:
# <bound method DataFrame.info of              lat        lng  \
# 0      40.297876 -75.581294
# 1      40.258061 -75.264680
# 2      40.121182 -75.351975
# 3      40.116153 -75.343513
# 4      40.251492 -75.603350
# 5      40.253473 -75.283245
# 6      40.182111 -75.127795
# 7      40.217286 -75.405182
# 8      40.289027 -75.399590
# 9      40.102398 -75.291458
# 10     40.231990 -75.251891
# 11     40.084161 -75.308386
# 12     40.174131 -75.098491
# 13     40.062974 -75.135914
# 14     40.097222 -75.376195
# 15     40.223778 -75.235399
# 16     40.243258 -75.286552
# 17     40.312181 -75.574260
# 18     40.114239 -75.338508
# 19     40.209337 -75.135266
# 20     40.114239 -75.338508
# 21     40.117948 -75.209848
# 22     40.199006 -75.300058
# 23     40.143326 -75.422819
# 24     40.153268 -75.189558
# 25     40.133037 -75.408463
# 26     40.155283 -75.264230
# 27     40.028903 -75.351822
# 28     40.097222 -75.376195
# 29     40.209337 -75.135266
# ...          ...        ...
# 99462  40.274137 -75.660469
# 99463  40.254768 -75.660459
# 99464  40.163730 -75.082753
# 99465  40.114928 -75.340307
# 99466  40.159820 -75.288436
# 99467  40.255271 -75.340722
# 99468  40.088355 -75.382100
# 99469  40.123868 -75.341678
# 99470  40.185798 -75.536484
# 99471  40.000763 -75.279769
# 99472  40.129398 -75.332213
# 99473  40.133533 -75.056460
# 99474  40.078678 -75.086943
# 99475  40.133715 -75.229630
# 99476  40.257820 -75.624294
# 99477  40.095652 -75.244877
# 99478  40.100344 -75.293955
# 99479  40.221227 -75.288737
# 99480  40.221227 -75.288737
# 99481  40.221227 -75.288737
# 99482  40.340072 -75.591709
# 99483  40.084465 -75.390173
# 99484  40.133037 -75.408463
# 99485  40.143601 -75.427877
# 99486  40.179225 -75.180572
# 99487  40.132869 -75.333515
# 99488  40.006974 -75.289080
# 99489  40.115429 -75.334679
# 99490  40.186431 -75.192555
# 99491  40.207055 -75.317952
#
#                                                     desc      zip  \
# 0      REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1      BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2      HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3      AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4      CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# 5      CANNON AVE & W 9TH ST;  LANSDALE; Station 345;...  19446.0
# 6      LAUREL AVE & OAKDALE AVE;  HORSHAM; Station 35...  19044.0
# 7      COLLEGEVILLE RD & LYWISKI RD;  SKIPPACK; Stati...  19426.0
# 8      MAIN ST & OLD SUMNEYTOWN PIKE;  LOWER SALFORD;...  19438.0
# 9      BLUEROUTE  & RAMP I476 NB TO CHEMICAL RD; PLYM...  19462.0
# 10     RT202 PKWY & KNAPP RD; MONTGOMERY; 2015-12-10 ...      NaN
# 11     BROOK RD & COLWELL LN; PLYMOUTH; 2015-12-10 @ ...  19428.0
# 12     BYBERRY AVE & S WARMINSTER RD; UPPER MORELAND;...  19040.0
# 13     OLD YORK RD & VALLEY RD; CHELTENHAM; 2015-12-1...  19027.0
# 14     SCHUYLKILL EXPY & CROTON RD UNDERPASS; UPPER M...      NaN
# 15     STUMP RD & WITCHWOOD DR; MONTGOMERY; 2015-12-1...  18936.0
# 16     SUSQUEHANNA AVE & W MAIN ST;  LANSDALE; Statio...  19446.0
# 17     CHARLOTTE ST & MILES RD;  NEW HANOVER; Station...  19525.0
# 18     PENN ST & ARCH ST;  NORRISTOWN; Station 308A; ...  19401.0
# 19     COUNTY LINE RD & WILLOW DR; HORSHAM; 2015-12-1...  18974.0
# 20     PENN ST & ARCH ST; NORRISTOWN; 2015-12-10 @ 17...  19401.0
# 21     CHURCH RD & REDCOAT DR; WHITEMARSH; 2015-12-10...  19031.0
# 22     LILAC CT & PRIMROSE DR; UPPER GWYNEDD; 2015-12...  19446.0
# 23     RT422  & PAWLINGS RD OVERPASS; LOWER PROVIDENC...      NaN
# 24     SUMMIT AVE & RT309 UNDERPASS; UPPER DUBLIN; 20...      NaN
# 25     SHANNONDELL DR & SHANNONDELL BLVD;  LOWER PROV...  19403.0
# 26     PENLLYN BLUE BELL PIKE & VILLAGE CIR;  WHITPAI...  19422.0
# 27     EDENTON PL & DURHAM DR; DELAWARE COUNTY; 2015-...  19085.0
# 28     SCHUYLKILL EXPY & WEADLEY RD OVERPASS; UPPER M...      NaN
# 29     COUNTY LINE RD & WILLOW DR; HORSHAM; 2015-12-1...  18974.0
# ...                                                  ...      ...
# 99462  UPLAND SQUARE DR & SELL RD;  WEST POTTSGROVE; ...  19464.0
# 99463  SHOEMAKER RD & ROBINSON ST;  POTTSTOWN; Statio...  19464.0
# 99464  KAREN LN & BYBERRY RD;  UPPER MORELAND; Statio...  19040.0
# 99465  AIRY ST & GREEN ST;  NORRISTOWN; Station 308A;...  19401.0
# 99466  WENTZ RD & SILO CIR;  WHITPAIN; Station 385; 2...  19422.0
# 99467  WOODS DR & DETWILER RD;  TOWAMENCIN; Station 3...  19446.0
# 99468  DEKALB PIKE & ALLENDALE RD; UPPER MERION; 2016...  19406.0
# 99469  MARKLEY ST & JAMES ST; NORRISTOWN; 2016-08-24 ...  19401.0
# 99470  WALNUT ST & S 5TH AVE;  ROYERSFORD; Station 32...  19468.0
# 99471  WYNNEWOOD RD & W OLD WYNNEWOOD RD;  LOWER MERI...  19096.0
# 99472  PINE ST & W ROBERTS ST;  NORRISTOWN; Station 3...  19401.0
# 99473  BUCK RD & WAVERLY LN;  BRYN ATHYN; Station 355...  19009.0
# 99474  HUNTINGDON PIKE & FILLMORE ST;  ROCKLEDGE; Sta...  19046.0
# 99475  SHEAFF LN & WHITEMARSH VALLEY RD; WHITEMARSH; ...  19034.0
# 99476  PARK DR & N ADAMS ST;  POTTSTOWN; Station 329;...  19464.0
# 99477  FOX HOUND DR & MARBLE HL;  WHITEMARSH; Station...  19444.0
# 99478  CHEMICAL RD & GALLAGHER RD; PLYMOUTH; 2016-08-...  19462.0
# 99479  SUMNEYTOWN PIKE & RR OVERPASS;  UPPER GWYNEDD;...      NaN
# 99480  SUMNEYTOWN PIKE & RR OVERPASS;  UPPER GWYNEDD;...      NaN
# 99481  SUMNEYTOWN PIKE & RR OVERPASS;  UPPER GWYNEDD;...      NaN
# 99482  RT100 SB & E PHILADELPHIA AVE OVERPASS; DOUGLA...      NaN
# 99483  DEKALB PIKE & KING OF PRUSSIA RD;  UPPER MERIO...  19406.0
# 99484  SHANNONDELL DR & SHANNONDELL BLVD; LOWER PROVI...  19403.0
# 99485  EAGLEVILLE RD & REDTAIL RD; LOWER PROVIDENCE; ...  19403.0
# 99486  WELSH RD & NORRISTOWN RD; HORSHAM; 2016-08-24 ...  19044.0
# 99487  MARKLEY ST & W LOGAN ST; NORRISTOWN; 2016-08-2...  19401.0
# 99488  LANCASTER AVE & RITTENHOUSE PL; LOWER MERION; ...  19003.0
# 99489  CHESTNUT ST & WALNUT ST;  NORRISTOWN; Station ...  19401.0
# 99490  WELSH RD & WEBSTER LN;  HORSHAM; Station 352; ...  19002.0
# 99491  MORRIS RD & S BROAD ST; UPPER GWYNEDD; 2016-08...  19446.0
#
#                                 title            timeStamp                twp  \
# 0              EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1             EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2                 Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00         NORRISTOWN
# 3              EMS: CARDIAC EMERGENCY  2015-12-10 17:40:01         NORRISTOWN
# 4                      EMS: DIZZINESS  2015-12-10 17:40:01   LOWER POTTSGROVE
# 5                    EMS: HEAD INJURY  2015-12-10 17:40:01           LANSDALE
# 6                EMS: NAUSEA/VOMITING  2015-12-10 17:40:01            HORSHAM
# 7          EMS: RESPIRATORY EMERGENCY  2015-12-10 17:40:01           SKIPPACK
# 8               EMS: SYNCOPAL EPISODE  2015-12-10 17:40:01      LOWER SALFORD
# 9         Traffic: VEHICLE ACCIDENT -  2015-12-10 17:40:01           PLYMOUTH
# 10        Traffic: VEHICLE ACCIDENT -  2015-12-10 17:40:01         MONTGOMERY
# 11        Traffic: VEHICLE ACCIDENT -  2015-12-10 17:40:02           PLYMOUTH
# 12        Traffic: VEHICLE ACCIDENT -  2015-12-10 17:40:02     UPPER MORELAND
# 13        Traffic: VEHICLE ACCIDENT -  2015-12-10 17:40:02         CHELTENHAM
# 14        Traffic: VEHICLE ACCIDENT -  2015-12-10 17:40:02       UPPER MERION
# 15        Traffic: VEHICLE ACCIDENT -  2015-12-10 17:40:02         MONTGOMERY
# 16         EMS: RESPIRATORY EMERGENCY  2015-12-10 17:46:01           LANSDALE
# 17                     EMS: DIZZINESS  2015-12-10 17:47:01        NEW HANOVER
# 18              EMS: VEHICLE ACCIDENT  2015-12-10 17:47:01         NORRISTOWN
# 19        Traffic: DISABLED VEHICLE -  2015-12-10 17:47:02            HORSHAM
# 20        Traffic: VEHICLE ACCIDENT -  2015-12-10 17:47:02         NORRISTOWN
# 21        Traffic: DISABLED VEHICLE -  2015-12-10 17:57:02         WHITEMARSH
# 22               Fire: APPLIANCE FIRE  2015-12-10 18:02:01      UPPER GWYNEDD
# 23        Traffic: DISABLED VEHICLE -  2015-12-10 18:02:02   LOWER PROVIDENCE
# 24        Traffic: VEHICLE ACCIDENT -  2015-12-10 18:02:02       UPPER DUBLIN
# 25              EMS: GENERAL WEAKNESS  2015-12-10 18:06:25   LOWER PROVIDENCE
# 26                   EMS: HEAD INJURY  2015-12-10 18:06:25           WHITPAIN
# 27     Fire: CARBON MONOXIDE DETECTOR  2015-12-10 18:06:25    DELAWARE COUNTY
# 28        Traffic: VEHICLE ACCIDENT -  2015-12-10 18:06:26       UPPER MERION
# 29        Traffic: DISABLED VEHICLE -  2015-12-10 18:11:01            HORSHAM
# ...                               ...                  ...                ...
# 99462  EMS: UNKNOWN MEDICAL EMERGENCY  2016-08-24 09:41:00    WEST POTTSGROVE
# 99463  EMS: UNKNOWN MEDICAL EMERGENCY  2016-08-24 09:42:00          POTTSTOWN
# 99464                EMS: FALL VICTIM  2016-08-24 09:51:06     UPPER MORELAND
# 99465      EMS: RESPIRATORY EMERGENCY  2016-08-24 09:56:13         NORRISTOWN
# 99466            EMS: NAUSEA/VOMITING  2016-08-24 10:01:00           WHITPAIN
# 99467      EMS: ALTERED MENTAL STATUS  2016-08-24 10:12:01         TOWAMENCIN
# 99468                Fire: FIRE ALARM  2016-08-24 10:12:01       UPPER MERION
# 99469                Fire: FIRE ALARM  2016-08-24 10:12:01         NORRISTOWN
# 99470      EMS: ALTERED MENTAL STATUS  2016-08-24 10:17:01         ROYERSFORD
# 99471      EMS: RESPIRATORY EMERGENCY  2016-08-24 10:17:01       LOWER MERION
# 99472          EMS: CARDIAC EMERGENCY  2016-08-24 10:22:00         NORRISTOWN
# 99473           EMS: GENERAL WEAKNESS  2016-08-24 10:27:01         BRYN ATHYN
# 99474                   EMS: SEIZURES  2016-08-24 10:27:01          ROCKLEDGE
# 99475     Traffic: VEHICLE ACCIDENT -  2016-08-24 10:32:01         WHITEMARSH
# 99476      EMS: RESPIRATORY EMERGENCY  2016-08-24 10:47:00          POTTSTOWN
# 99477            EMS: SUBJECT IN PAIN  2016-08-24 10:47:00         WHITEMARSH
# 99478     Traffic: VEHICLE ACCIDENT -  2016-08-24 10:47:02           PLYMOUTH
# 99479          EMS: CARDIAC EMERGENCY  2016-08-24 10:52:01      UPPER GWYNEDD
# 99480         EMS: DIABETIC EMERGENCY  2016-08-24 10:52:01      UPPER GWYNEDD
# 99481                  EMS: DIZZINESS  2016-08-24 10:52:01      UPPER GWYNEDD
# 99482     Traffic: DISABLED VEHICLE -  2016-08-24 10:52:03           DOUGLASS
# 99483          EMS: BACK PAINS/INJURY  2016-08-24 10:57:00       UPPER MERION
# 99484                Fire: FIRE ALARM  2016-08-24 10:57:00   LOWER PROVIDENCE
# 99485     Traffic: DISABLED VEHICLE -  2016-08-24 10:57:01   LOWER PROVIDENCE
# 99486     Traffic: VEHICLE ACCIDENT -  2016-08-24 11:02:02            HORSHAM
# 99487     Traffic: VEHICLE ACCIDENT -  2016-08-24 11:06:00         NORRISTOWN
# 99488     Traffic: VEHICLE ACCIDENT -  2016-08-24 11:07:02       LOWER MERION
# 99489                EMS: FALL VICTIM  2016-08-24 11:12:00         NORRISTOWN
# 99490            EMS: NAUSEA/VOMITING  2016-08-24 11:17:01            HORSHAM
# 99491     Traffic: VEHICLE ACCIDENT -  2016-08-24 11:17:02      UPPER GWYNEDD
#
#                                            addr  e
# 0                        REINDEER CT & DEAD END  1
# 1                    BRIAR PATH & WHITEMARSH LN  1
# 2                                      HAWS AVE  1
# 3                            AIRY ST & SWEDE ST  1
# 4                      CHERRYWOOD CT & DEAD END  1
# 5                         CANNON AVE & W 9TH ST  1
# 6                      LAUREL AVE & OAKDALE AVE  1
# 7                  COLLEGEVILLE RD & LYWISKI RD  1
# 8                 MAIN ST & OLD SUMNEYTOWN PIKE  1
# 9      BLUEROUTE  & RAMP I476 NB TO CHEMICAL RD  1
# 10                        RT202 PKWY & KNAPP RD  1
# 11                        BROOK RD & COLWELL LN  1
# 12                BYBERRY AVE & S WARMINSTER RD  1
# 13                      OLD YORK RD & VALLEY RD  1
# 14        SCHUYLKILL EXPY & CROTON RD UNDERPASS  1
# 15                      STUMP RD & WITCHWOOD DR  1
# 16                  SUSQUEHANNA AVE & W MAIN ST  1
# 17                      CHARLOTTE ST & MILES RD  1
# 18                            PENN ST & ARCH ST  1
# 19                   COUNTY LINE RD & WILLOW DR  1
# 20                            PENN ST & ARCH ST  1
# 21                       CHURCH RD & REDCOAT DR  1
# 22                       LILAC CT & PRIMROSE DR  1
# 23                RT422  & PAWLINGS RD OVERPASS  1
# 24                 SUMMIT AVE & RT309 UNDERPASS  1
# 25            SHANNONDELL DR & SHANNONDELL BLVD  1
# 26         PENLLYN BLUE BELL PIKE & VILLAGE CIR  1
# 27                       EDENTON PL & DURHAM DR  1
# 28        SCHUYLKILL EXPY & WEADLEY RD OVERPASS  1
# 29                   COUNTY LINE RD & WILLOW DR  1
# ...                                         ... ..
# 99462                UPLAND SQUARE DR & SELL RD  1
# 99463                SHOEMAKER RD & ROBINSON ST  1
# 99464                     KAREN LN & BYBERRY RD  1
# 99465                        AIRY ST & GREEN ST  1
# 99466                       WENTZ RD & SILO CIR  1
# 99467                    WOODS DR & DETWILER RD  1
# 99468                DEKALB PIKE & ALLENDALE RD  1
# 99469                     MARKLEY ST & JAMES ST  1
# 99470                     WALNUT ST & S 5TH AVE  1
# 99471         WYNNEWOOD RD & W OLD WYNNEWOOD RD  1
# 99472                    PINE ST & W ROBERTS ST  1
# 99473                      BUCK RD & WAVERLY LN  1
# 99474             HUNTINGDON PIKE & FILLMORE ST  1
# 99475          SHEAFF LN & WHITEMARSH VALLEY RD  1
# 99476                      PARK DR & N ADAMS ST  1
# 99477                  FOX HOUND DR & MARBLE HL  1
# 99478                CHEMICAL RD & GALLAGHER RD  1
# 99479             SUMNEYTOWN PIKE & RR OVERPASS  1
# 99480             SUMNEYTOWN PIKE & RR OVERPASS  1
# 99481             SUMNEYTOWN PIKE & RR OVERPASS  1
# 99482    RT100 SB & E PHILADELPHIA AVE OVERPASS  1
# 99483          DEKALB PIKE & KING OF PRUSSIA RD  1
# 99484         SHANNONDELL DR & SHANNONDELL BLVD  1
# 99485                EAGLEVILLE RD & REDTAIL RD  1
# 99486                  WELSH RD & NORRISTOWN RD  1
# 99487                   MARKLEY ST & W LOGAN ST  1
# 99488            LANCASTER AVE & RITTENHOUSE PL  1
# 99489                   CHESTNUT ST & WALNUT ST  1
# 99490                     WELSH RD & WEBSTER LN  1
# 99491                    MORRIS RD & S BROAD ST  1
#
# [99492 rows x 9 columns]>

# %% [markdown]
# ** Check the head of df **

# %%
df.head(2)
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
#
#                          addr  e
# 0      REINDEER CT & DEAD END  1
# 1  BRIAR PATH & WHITEMARSH LN  1

# %% [markdown]
# ## Basic Questions

# %% [markdown]
# ** What are the top 5 zipcodes for 911 calls? **

# %%
df['zip'].head()
# Out:
# 0    19525.0
# 1    19446.0
# 2    19401.0
# 3    19401.0
# 4        NaN
# Name: zip, dtype: float64

# %% [markdown]
# ** What are the top 5 townships (twp) for 911 calls? **

# %%
df.groupby(['twp']).head(5)
# Out:
#              lat        lng  \
# 0      40.297876 -75.581294
# 1      40.258061 -75.264680
# 2      40.121182 -75.351975
# 3      40.116153 -75.343513
# 4      40.251492 -75.603350
# 5      40.253473 -75.283245
# 6      40.182111 -75.127795
# 7      40.217286 -75.405182
# 8      40.289027 -75.399590
# 9      40.102398 -75.291458
# 10     40.231990 -75.251891
# 11     40.084161 -75.308386
# 12     40.174131 -75.098491
# 13     40.062974 -75.135914
# 14     40.097222 -75.376195
# 15     40.223778 -75.235399
# 16     40.243258 -75.286552
# 17     40.312181 -75.574260
# 18     40.114239 -75.338508
# 19     40.209337 -75.135266
# 20     40.114239 -75.338508
# 21     40.117948 -75.209848
# 22     40.199006 -75.300058
# 23     40.143326 -75.422819
# 24     40.153268 -75.189558
# 25     40.133037 -75.408463
# 26     40.155283 -75.264230
# 27     40.028903 -75.351822
# 28     40.097222 -75.376195
# 29     40.209337 -75.135266
# ...          ...        ...
# 2397   40.348705 -75.631560
# 2399   40.341148 -75.630056
# 2415   40.249820 -75.680960
# 2462   40.229008 -75.387853
# 2647   40.280515 -75.435780
# 2664   40.376054 -75.483257
# 2749   40.429863 -75.558330
# 2919   40.340434 -75.472335
# 3029   40.375647 -75.485276
# 3248   40.229008 -75.387853
# 3705   40.200754 -75.482719
# 3826   40.199028 -75.476592
# 3938   40.261232 -75.461180
# 4442   40.187913 -75.479740
# 4447   40.192513 -75.475190
# 4597   40.479853 -75.510815
# 4598   40.479853 -75.510815
# 5488   40.222272 -75.138302
# 6595   40.444123 -75.488292
# 7323   40.113516 -75.332257
# 7726   40.229008 -75.387853
# 7747   40.368249 -75.483100
# 8352   40.339335 -75.471759
# 14672  39.989800 -75.250816
# 15060  40.339335 -75.471759
# 15061  40.339335 -75.471759
# 15223  40.087959 -75.073465
# 15730  39.988310 -75.253975
# 19880  40.070666 -75.241225
# 22101  40.067488 -75.146691
#
#                                                     desc      zip  \
# 0      REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1      BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2      HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3      AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4      CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# 5      CANNON AVE & W 9TH ST;  LANSDALE; Station 345;...  19446.0
# 6      LAUREL AVE & OAKDALE AVE;  HORSHAM; Station 35...  19044.0
# 7      COLLEGEVILLE RD & LYWISKI RD;  SKIPPACK; Stati...  19426.0
# 8      MAIN ST & OLD SUMNEYTOWN PIKE;  LOWER SALFORD;...  19438.0
# 9      BLUEROUTE  & RAMP I476 NB TO CHEMICAL RD; PLYM...  19462.0
# 10     RT202 PKWY & KNAPP RD; MONTGOMERY; 2015-12-10 ...      NaN
# 11     BROOK RD & COLWELL LN; PLYMOUTH; 2015-12-10 @ ...  19428.0
# 12     BYBERRY AVE & S WARMINSTER RD; UPPER MORELAND;...  19040.0
# 13     OLD YORK RD & VALLEY RD; CHELTENHAM; 2015-12-1...  19027.0
# 14     SCHUYLKILL EXPY & CROTON RD UNDERPASS; UPPER M...      NaN
# 15     STUMP RD & WITCHWOOD DR; MONTGOMERY; 2015-12-1...  18936.0
# 16     SUSQUEHANNA AVE & W MAIN ST;  LANSDALE; Statio...  19446.0
# 17     CHARLOTTE ST & MILES RD;  NEW HANOVER; Station...  19525.0
# 18     PENN ST & ARCH ST;  NORRISTOWN; Station 308A; ...  19401.0
# 19     COUNTY LINE RD & WILLOW DR; HORSHAM; 2015-12-1...  18974.0
# 20     PENN ST & ARCH ST; NORRISTOWN; 2015-12-10 @ 17...  19401.0
# 21     CHURCH RD & REDCOAT DR; WHITEMARSH; 2015-12-10...  19031.0
# 22     LILAC CT & PRIMROSE DR; UPPER GWYNEDD; 2015-12...  19446.0
# 23     RT422  & PAWLINGS RD OVERPASS; LOWER PROVIDENC...      NaN
# 24     SUMMIT AVE & RT309 UNDERPASS; UPPER DUBLIN; 20...      NaN
# 25     SHANNONDELL DR & SHANNONDELL BLVD;  LOWER PROV...  19403.0
# 26     PENLLYN BLUE BELL PIKE & VILLAGE CIR;  WHITPAI...  19422.0
# 27     EDENTON PL & DURHAM DR; DELAWARE COUNTY; 2015-...  19085.0
# 28     SCHUYLKILL EXPY & WEADLEY RD OVERPASS; UPPER M...      NaN
# 29     COUNTY LINE RD & WILLOW DR; HORSHAM; 2015-12-1...  18974.0
# ...                                                  ...      ...
# 2397   N READING AVE;  BERKS COUNTY; Station EMS; 201...      NaN
# 2399   N READING AVE & BRICKYARD LN; BERKS COUNTY; 20...  19512.0
# 2415   LEMON ST & JEFFERSON ST;  WEST POTTSGROVE; Sta...  19464.0
# 2462   CHESTNUT ST & DEAD END; HATFIELD BORO; 2015-12...      NaN
# 2647   SCHWENKSVILLE RD & SALFORD STATION RD; UPPER S...  19473.0
# 2664   GRABER ALY & W 5TH ST; RED HILL; 2015-12-17 @ ...  18076.0
# 2749   FETTERMAN RD;  BERKS COUNTY; Station EMS; 2015...  19504.0
# 2919   GRAVEL PIKE & LUMBER ST;  GREEN LANE; Station ...  18054.0
# 3029   APPLE ST & MIMOSA CT;  RED HILL; Station 369; ...  18076.0
# 3248   WHEATFIELD CIR & TOWAMENCIN AVE; HATFIELD BORO...      NaN
# 3705   HOLLY DR & ASH ST;  TRAPPE; Station 324; 2015-...  19426.0
# 3826   MAIN ST & W 5TH AVE;  TRAPPE; Station 324; 201...  19426.0
# 3938   SCHWENKSVILLE RD & E PARK AVE;  UPPER SALFORD;...  19473.0
# 4442   W 3RD AVE & BORO LINE RD; TRAPPE; 2015-12-22 @...  19426.0
# 4447   W 3RD AVE; TRAPPE; 2015-12-22 @ 15:15:06-Stati...  19426.0
# 4597   KINGS HWY S;  LEHIGH COUNTY; Station 369; 2015...  18092.0
# 4598   KINGS HWY S; LEHIGH COUNTY; 2015-12-22 @ 20:35...  18092.0
# 5488       GIANT; ; 2015-12-24 @ 17:30:07-Station:STA98;  18976.0
# 6595   KINGS HWY & W MILL HILL RD;  LEHIGH COUNTY; St...  18041.0
# 7323     HIGH ST;  ; Station 329; 2015-12-30 @ 03:32:49;  19401.0
# 7726   NO LOCATION - NEIGHBORING COUNTY;  LEHIGH COUN...      NaN
# 7747   MAIN ST & 2ND ST;  GREEN LANE; Station 344A; 2...  18076.0
# 8352   GRAVEL PIKE & MACOBY ST; GREEN LANE; 2016-01-0...  18054.0
# 14672  CITY AVE & N 63RD ST; PHILA COUNTY; 2016-01-18...  19151.0
# 15060  GRAVEL PIKE & MACOBY ST; GREEN LANE; 2016-01-1...  18054.0
# 15061  GRAVEL PIKE & MACOBY ST; GREEN LANE; 2016-01-1...  18054.0
# 15223  PINE RD & SHADY LN; PHILA COUNTY; 2016-01-19 @...  19111.0
# 15730  CITY AVE & LANCASTER AVE; PHILA COUNTY; 2016-0...  19151.0
# 19880  RIDGE AVE & BELLS MILL RD; PHILA COUNTY; 2016-...  19128.0
# 22101  CHELTENHAM AVE & N 19TH ST; PHILA COUNTY; 2016...  19138.0
#
#                                      title            timeStamp  \
# 0                   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00
# 1                  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00
# 2                      Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00
# 3                   EMS: CARDIAC EMERGENCY  2015-12-10 17:40:01
# 4                           EMS: DIZZINESS  2015-12-10 17:40:01
# 5                         EMS: HEAD INJURY  2015-12-10 17:40:01
# 6                     EMS: NAUSEA/VOMITING  2015-12-10 17:40:01
# 7               EMS: RESPIRATORY EMERGENCY  2015-12-10 17:40:01
# 8                    EMS: SYNCOPAL EPISODE  2015-12-10 17:40:01
# 9              Traffic: VEHICLE ACCIDENT -  2015-12-10 17:40:01
# 10             Traffic: VEHICLE ACCIDENT -  2015-12-10 17:40:01
# 11             Traffic: VEHICLE ACCIDENT -  2015-12-10 17:40:02
# 12             Traffic: VEHICLE ACCIDENT -  2015-12-10 17:40:02
# 13             Traffic: VEHICLE ACCIDENT -  2015-12-10 17:40:02
# 14             Traffic: VEHICLE ACCIDENT -  2015-12-10 17:40:02
# 15             Traffic: VEHICLE ACCIDENT -  2015-12-10 17:40:02
# 16              EMS: RESPIRATORY EMERGENCY  2015-12-10 17:46:01
# 17                          EMS: DIZZINESS  2015-12-10 17:47:01
# 18                   EMS: VEHICLE ACCIDENT  2015-12-10 17:47:01
# 19             Traffic: DISABLED VEHICLE -  2015-12-10 17:47:02
# 20             Traffic: VEHICLE ACCIDENT -  2015-12-10 17:47:02
# 21             Traffic: DISABLED VEHICLE -  2015-12-10 17:57:02
# 22                    Fire: APPLIANCE FIRE  2015-12-10 18:02:01
# 23             Traffic: DISABLED VEHICLE -  2015-12-10 18:02:02
# 24             Traffic: VEHICLE ACCIDENT -  2015-12-10 18:02:02
# 25                   EMS: GENERAL WEAKNESS  2015-12-10 18:06:25
# 26                        EMS: HEAD INJURY  2015-12-10 18:06:25
# 27          Fire: CARBON MONOXIDE DETECTOR  2015-12-10 18:06:25
# 28             Traffic: VEHICLE ACCIDENT -  2015-12-10 18:06:26
# 29             Traffic: DISABLED VEHICLE -  2015-12-10 18:11:01
# ...                                    ...                  ...
# 2397                 EMS: VEHICLE ACCIDENT  2015-12-16 18:22:02
# 2399           Traffic: VEHICLE ACCIDENT -  2015-12-16 18:22:04
# 2415                   EMS: ASSAULT VICTIM  2015-12-16 19:21:01
# 2462        Fire: CARBON MONOXIDE DETECTOR  2015-12-16 22:02:02
# 2647           Traffic: VEHICLE ACCIDENT -  2015-12-17 13:42:03
# 2664                      Fire: FIRE ALARM  2015-12-17 14:12:02
# 2749                 EMS: VEHICLE ACCIDENT  2015-12-17 17:22:02
# 2919            EMS: RESPIRATORY EMERGENCY  2015-12-18 10:52:00
# 3029                EMS: BACK PAINS/INJURY  2015-12-18 14:52:01
# 3248        Fire: CARBON MONOXIDE DETECTOR  2015-12-19 10:32:01
# 3705                 EMS: GENERAL WEAKNESS  2015-12-20 18:32:00
# 3826                         EMS: SEIZURES  2015-12-21 06:57:01
# 3938                        EMS: DIZZINESS  2015-12-21 12:47:01
# 4442           Traffic: VEHICLE ACCIDENT -  2015-12-22 15:02:01
# 4447                Fire: VEHICLE ACCIDENT  2015-12-22 15:16:01
# 4597                 EMS: VEHICLE ACCIDENT  2015-12-22 20:37:01
# 4598                Fire: VEHICLE ACCIDENT  2015-12-22 20:37:01
# 5488                Fire: VEHICLE ACCIDENT  2015-12-24 17:31:01
# 6595                EMS: BACK PAINS/INJURY  2015-12-28 07:27:01
# 7323                 EMS: VEHICLE ACCIDENT  2015-12-30 03:36:01
# 7726                EMS: CARDIAC EMERGENCY  2015-12-31 09:52:00
# 7747                      EMS: FALL VICTIM  2015-12-31 10:51:00
# 8352           Traffic: VEHICLE ACCIDENT -  2016-01-02 12:17:02
# 14672          Traffic: DISABLED VEHICLE -  2016-01-18 10:17:02
# 15060       Fire: DEBRIS/FLUIDS ON HIGHWAY  2016-01-19 11:16:00
# 15061  Traffic: DEBRIS/FLUIDS ON HIGHWAY -  2016-01-19 11:16:02
# 15223          Traffic: DISABLED VEHICLE -  2016-01-19 17:37:01
# 15730          Traffic: VEHICLE ACCIDENT -  2016-01-20 23:27:00
# 19880          Traffic: VEHICLE ACCIDENT -  2016-01-28 11:52:01
# 22101          Traffic: VEHICLE ACCIDENT -  2016-02-03 08:07:02
#
#                      twp                                      addr  e
# 0            NEW HANOVER                    REINDEER CT & DEAD END  1
# 1      HATFIELD TOWNSHIP                BRIAR PATH & WHITEMARSH LN  1
# 2             NORRISTOWN                                  HAWS AVE  1
# 3             NORRISTOWN                        AIRY ST & SWEDE ST  1
# 4       LOWER POTTSGROVE                  CHERRYWOOD CT & DEAD END  1
# 5               LANSDALE                     CANNON AVE & W 9TH ST  1
# 6                HORSHAM                  LAUREL AVE & OAKDALE AVE  1
# 7               SKIPPACK              COLLEGEVILLE RD & LYWISKI RD  1
# 8          LOWER SALFORD             MAIN ST & OLD SUMNEYTOWN PIKE  1
# 9               PLYMOUTH  BLUEROUTE  & RAMP I476 NB TO CHEMICAL RD  1
# 10            MONTGOMERY                     RT202 PKWY & KNAPP RD  1
# 11              PLYMOUTH                     BROOK RD & COLWELL LN  1
# 12        UPPER MORELAND             BYBERRY AVE & S WARMINSTER RD  1
# 13            CHELTENHAM                   OLD YORK RD & VALLEY RD  1
# 14          UPPER MERION     SCHUYLKILL EXPY & CROTON RD UNDERPASS  1
# 15            MONTGOMERY                   STUMP RD & WITCHWOOD DR  1
# 16              LANSDALE               SUSQUEHANNA AVE & W MAIN ST  1
# 17           NEW HANOVER                   CHARLOTTE ST & MILES RD  1
# 18            NORRISTOWN                         PENN ST & ARCH ST  1
# 19               HORSHAM                COUNTY LINE RD & WILLOW DR  1
# 20            NORRISTOWN                         PENN ST & ARCH ST  1
# 21            WHITEMARSH                    CHURCH RD & REDCOAT DR  1
# 22         UPPER GWYNEDD                    LILAC CT & PRIMROSE DR  1
# 23      LOWER PROVIDENCE             RT422  & PAWLINGS RD OVERPASS  1
# 24          UPPER DUBLIN              SUMMIT AVE & RT309 UNDERPASS  1
# 25      LOWER PROVIDENCE         SHANNONDELL DR & SHANNONDELL BLVD  1
# 26              WHITPAIN      PENLLYN BLUE BELL PIKE & VILLAGE CIR  1
# 27       DELAWARE COUNTY                    EDENTON PL & DURHAM DR  1
# 28          UPPER MERION     SCHUYLKILL EXPY & WEADLEY RD OVERPASS  1
# 29               HORSHAM                COUNTY LINE RD & WILLOW DR  1
# ...                  ...                                       ... ..
# 2397        BERKS COUNTY                             N READING AVE  1
# 2399        BERKS COUNTY              N READING AVE & BRICKYARD LN  1
# 2415     WEST POTTSGROVE                   LEMON ST & JEFFERSON ST  1
# 2462       HATFIELD BORO                    CHESTNUT ST & DEAD END  1
# 2647       UPPER SALFORD     SCHWENKSVILLE RD & SALFORD STATION RD  1
# 2664            RED HILL                     GRABER ALY & W 5TH ST  1
# 2749        BERKS COUNTY                              FETTERMAN RD  1
# 2919          GREEN LANE                   GRAVEL PIKE & LUMBER ST  1
# 3029            RED HILL                      APPLE ST & MIMOSA CT  1
# 3248       HATFIELD BORO           WHEATFIELD CIR & TOWAMENCIN AVE  1
# 3705              TRAPPE                         HOLLY DR & ASH ST  1
# 3826              TRAPPE                       MAIN ST & W 5TH AVE  1
# 3938       UPPER SALFORD             SCHWENKSVILLE RD & E PARK AVE  1
# 4442              TRAPPE                  W 3RD AVE & BORO LINE RD  1
# 4447              TRAPPE                                 W 3RD AVE  1
# 4597       LEHIGH COUNTY                               KINGS HWY S  1
# 4598       LEHIGH COUNTY                               KINGS HWY S  1
# 5488                 NaN                                     GIANT  1
# 6595       LEHIGH COUNTY                KINGS HWY & W MILL HILL RD  1
# 7323                 NaN                                   HIGH ST  1
# 7726       LEHIGH COUNTY          NO LOCATION - NEIGHBORING COUNTY  1
# 7747          GREEN LANE                          MAIN ST & 2ND ST  1
# 8352          GREEN LANE                   GRAVEL PIKE & MACOBY ST  1
# 14672       PHILA COUNTY                      CITY AVE & N 63RD ST  1
# 15060         GREEN LANE                   GRAVEL PIKE & MACOBY ST  1
# 15061         GREEN LANE                   GRAVEL PIKE & MACOBY ST  1
# 15223       PHILA COUNTY                        PINE RD & SHADY LN  1
# 15730       PHILA COUNTY                  CITY AVE & LANCASTER AVE  1
# 19880       PHILA COUNTY                 RIDGE AVE & BELLS MILL RD  1
# 22101       PHILA COUNTY                CHELTENHAM AVE & N 19TH ST  1
#
# [345 rows x 9 columns]

# %%
df['title'].nunique()
# Out:
# 110

# %% [markdown]
# ** Take a look at the 'title' column, how many unique title codes are there? **

# %%
df['Reason'] = df['title'].apply(lambda x: x.split(':')[0])
df['Reason']
# Out:
# 0            EMS
# 1            EMS
# 2           Fire
# 3            EMS
# 4            EMS
# 5            EMS
# 6            EMS
# 7            EMS
# 8            EMS
# 9        Traffic
# 10       Traffic
# 11       Traffic
# 12       Traffic
# 13       Traffic
# 14       Traffic
# 15       Traffic
# 16           EMS
# 17           EMS
# 18           EMS
# 19       Traffic
# 20       Traffic
# 21       Traffic
# 22          Fire
# 23       Traffic
# 24       Traffic
# 25           EMS
# 26           EMS
# 27          Fire
# 28       Traffic
# 29       Traffic
#           ...
# 99462        EMS
# 99463        EMS
# 99464        EMS
# 99465        EMS
# 99466        EMS
# 99467        EMS
# 99468       Fire
# 99469       Fire
# 99470        EMS
# 99471        EMS
# 99472        EMS
# 99473        EMS
# 99474        EMS
# 99475    Traffic
# 99476        EMS
# 99477        EMS
# 99478    Traffic
# 99479        EMS
# 99480        EMS
# 99481        EMS
# 99482    Traffic
# 99483        EMS
# 99484       Fire
# 99485    Traffic
# 99486    Traffic
# 99487    Traffic
# 99488    Traffic
# 99489        EMS
# 99490        EMS
# 99491    Traffic
# Name: Reason, Length: 99492, dtype: object

# %% [markdown]
# ## Creating new features

# %% [markdown]
# ** In the titles column there are "Reasons/Departments" specified before the title code. These are EMS, Fire, and Traffic. Use .apply() with a custom lambda expression to create a new column called "Reason" that contains this string value.**
#
# **For example, if the title column value is EMS: BACK PAINS/INJURY , the Reason column value would be EMS. **

# %%
df['Reason'].value_counts().head()
# Out:
# EMS        48877
# Traffic    35695
# Fire       14920
# Name: Reason, dtype: int64

# %% [markdown]
# ** What is the most common Reason for a 911 call based off of this new column? **

# %%
import seaborn as sns
sns.countplot(x='Reason', data=df)

# %% [markdown]
# ** Now use seaborn to create a countplot of 911 calls by Reason. **

# %%
type(df['timeStamp'].iloc[0])
# Out:
# str

# %% [markdown]
# ___
# ** Now let us begin to focus on time information. What is the data type of the objects in the timeStamp column? **

# %%
df['timeStamp'] = pd.to_datetime(df['timeStamp'])

# %% [markdown]
# ** You should have seen that these timestamps are still strings. Use [pd.to_datetime](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html) to convert the column from strings to DateTime objects. **

# %%
df['Hour']=df['timeStamp'].apply(lambda x: x.hour)
df['Month']=df['timeStamp'].apply(lambda x: x.month)
df['Day of Week']=df['timeStamp'].apply(lambda x: x.dayofweek)

# %% [markdown]
# ** You can now grab specific attributes from a Datetime object by calling them. For example:**
#
#     time = df['timeStamp'].iloc[0]
#     time.hour
#
# **You can use Jupyter's tab method to explore the various attributes you can call. Now that the timestamp column are actually DateTime objects, use .apply() to create 3 new columns called Hour, Month, and Day of Week. You will create these columns based off of the timeStamp column, reference the solutions if you get stuck on this step.**

# %%
dmap = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}

# %% [markdown]
# ** Notice how the Day of Week is an integer 0-6. Use the .map() with this dictionary to map the actual string names to the day of the week: **
#
#     dmap = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}

# %%
df['Day of Week'] = df['Day of Week'].map(dmap)

# %%
sns.countplot(x='Day of Week',data=df,hue='Reason',palette='viridis')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-41-5ab6d3a14c88> in <module>()
# ----> 1 sns.countplot(x='Day of Week',data=df,hue='Reason',palette='viridis')
#       2 plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3558         ax = plt.gca()
#    3559
# -> 3560     plotter.plot(ax, kwargs)
#    3561     return ax
#    3562
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, bar_kws)
#    1659     def plot(self, ax, bar_kws):
#    1660         """Make the plot."""
# -> 1661         self.draw_bars(ax, bar_kws)
#    1662         self.annotate_axes(ax)
#    1663         if self.orient == "h":
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in draw_bars(self, ax, kws)
#    1642                 # Draw the bars
#    1643                 offpos = barpos + self.hue_offsets[j]
# -> 1644                 barfunc(offpos, self.statistic[:, j], self.nested_width,
#    1645                         color=self.colors[j], align="center",
#    1646                         label=hue_level, **kws)
#
# IndexError: too many indices for array

# %% [markdown]
# ** Now use seaborn to create a countplot of the Day of Week column with the hue based off of the Reason column. **

# %% [markdown]
# **Now do the same for Month:**

# %% [markdown]
# **Did you notice something strange about the Plot?**
#
# _____
#
# ** You should have noticed it was missing some Months, let's see if we can maybe fill in this information by plotting the information in another way, possibly a simple line plot that fills in the missing months, in order to do this, we'll need to do some work with pandas... **

# %% [markdown]
# ** Now create a gropuby object called byMonth, where you group the DataFrame by the month column and use the count() method for aggregation. Use the head() method on this returned DataFrame. **

# %% [markdown]
# ** Now create a simple plot off of the dataframe indicating the count of calls per month. **

# %% [markdown]
# ** Now see if you can use seaborn's lmplot() to create a linear fit on the number of calls per month. Keep in mind you may need to reset the index to a column. **

# %% [markdown]
# **Create a new column called 'Date' that contains the date from the timeStamp column. You'll need to use apply along with the .date() method. **

# %% [markdown]
# ** Now groupby this Date column with the count() aggregate and create a plot of counts of 911 calls.**

# %% [markdown]
# ** Now recreate this plot but create 3 separate plots with each plot representing a Reason for the 911 call**

# %% [markdown]
# ____
# ** Now let's move on to creating  heatmaps with seaborn and our data. We'll first need to restructure the dataframe so that the columns become the Hours and the Index becomes the Day of the Week. There are lots of ways to do this, but I would recommend trying to combine groupby with an [unstack](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.unstack.html) method. Reference the solutions if you get stuck on this!**

# %% [markdown]
# ** Now create a HeatMap using this new DataFrame. **

# %% [markdown]
# ** Now create a clustermap using this DataFrame. **

# %% [markdown]
# ** Now repeat these same plots and operations, for a DataFrame that shows the Month as the column. **

# %% [markdown]
# **Continue exploring the Data however you see fit!**
# # Great Job!
